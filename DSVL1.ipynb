# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# TO read the CSV file
df = pd.read_csv("/content/diabetes.csv")

# %%
# to see below 5 rows
df.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
# to see shape of dataset
df.shape
# Out:
# (768, 9)

# %%
# to see the coumn names
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# How to see each datatypes of column
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# general info dataset
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
# statistical summary
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# To check the data quality

# %%
# check the missing value
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# to check the duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import numpy as np

# %%
# count unique values per column
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
# to check invalid zero values (real missing values)
(df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] == 0).sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %% [markdown]
# Selecting and Filtering the data

# %%
df['Age']
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
df[['BMI','Age','BloodPressure']]
# Out:
#       BMI  Age  BloodPressure
# 0    33.6   50             72
# 1    26.6   31             66
# 2    23.3   32             64
# 3    28.1   21             66
# 4    43.1   33             40
# ..    ...  ...            ...
# 763  32.9   63             76
# 764  36.8   27             70
# 765  26.2   30             72
# 766  30.1   47             60
# 767  30.4   23             70
#
# [768 rows x 3 columns]

# %% [markdown]
# to use multiple data frames/ columns use double square brackets

# %%
# filter the rows by condition (age > 50)
df[df['Age'] > 50]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 719            5       97             76             27        0  35.6
# 734            2      105             75              0        0  23.3
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 8                       0.158   53        1
# ...

# %%
# filter with multiple conditions
df[(df['Age'] > 50) & (df['Outcome']==1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 24            11      143             94             33      146  36.6
# 39             4      111             72             47      207  37.1
# 43             9      171            110             24      240  45.4
# 53             8      176             90             34      300  33.7
# 93             4      134             72              0        0  23.8
# 115            4      146             92              0        0  31.2
# 129            0      105             84              0        0  27.9
# 186            8      181             68             36      495  30.1
# ...

# %%
# Access by rows, Index(iloc)
df.iloc[4:7]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1

# %% [markdown]
# Sorting and Grouping

# %%
#sort by column
df.sort_values(by='Age').head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 123                     0.186   69        0
# 684                     0.640   69        0
# 666                     0.235   70        1
# 453                     0.832   72        0
# 459                     0.460   81        0

# %%
df.sort_values(by = 'Age', ascending = False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
# ..           ...      ...            ...            ...      ...   ...
# 736            0      126             86             27      120  27.4
# 273            1       71             78             50       45  33.2
# 713            0      134             58             20      291  26.4
# 290            0       78             88             29       40  36.9
# 3              1       89             66             23       94  28.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72             35      NaN  33.6
# 1              1     85.0             66             29      NaN  26.6
# 2              8    183.0             64              0      NaN  23.3
# 3              1     89.0             66             23     94.0  28.1
# 4              0    137.0             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0             76             48    180.0  32.9
# 764            2    122.0             70             27      NaN  36.8
# 765            5    121.0             72             23    112.0  26.2
# 766            1    126.0             60              0      NaN  30.1
# 767            1     93.0             70             31      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Replace invalid zeroes with column or vice versa
df['Insulin'] = df['Insulin'].replace(np.nan,0)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72             35      0.0  33.6
# 1              1     85.0             66             29      0.0  26.6
# 2              8    183.0             64              0      0.0  23.3
# 3              1     89.0             66             23     94.0  28.1
# 4              0    137.0             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0             76             48    180.0  32.9
# 764            2    122.0             70             27    180.0  36.8
# 765            5    121.0             72             23    112.0  26.2
# 766            1    126.0             60              0    112.0  30.1
# 767            1     93.0             70             31    112.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Insulin'] = df['Insulin'].replace(0, df['Insulin'].mean())

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0             72             35  156.717448  33.6
# 1              1     85.0             66             29  156.717448  26.6
# 2              8    183.0             64              0  156.717448  23.3
# 3              1     89.0             66             23   94.000000  28.1
# 4              0    137.0             40             35  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0             76             48  180.000000  32.9
# 764            2    122.0             70             27  180.000000  36.8
# 765            5    121.0             72             23  112.000000  26.2
# 766            1    126.0             60              0  112.000000  30.1
# 767            1     93.0             70             31  112.000000  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# coorelation heatmap of dataset
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True), annot = True, cmap = 'coolwarm')
plt.title('Correlation Heatmap')
plt.show()
